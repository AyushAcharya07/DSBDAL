# %%
import pandas as pd
import numpy as num
import matplotlib.pyplot as mat
import seaborn as sns

# %%
df=pd.read_csv("titanic.csv")

# %%
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df.dtypes
# Out:
# survived         int64
# pclass           int64
# sex             object
# age            float64
# sibsp            int64
# parch            int64
# fare           float64
# embarked        object
# class           object
# who             object
# adult_male        bool
# deck            object
# embark_town     object
# alive           object
# alone             bool
# dtype: object

# %%
df.shape
# Out:
# (891, 15)

# %%
df.size
# Out:
# 13365

# %%
df.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
df.isna().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
df["age"].fillna(df["age"].mean(),inplace=True) 
cnt=df['age'].isna().sum()
print(cnt)
# Out:
# 0

# %%
df["deck"].ffill(inplace=True) 
cnt2=df['deck'].isna().sum() 
print(cnt2)
# Out:
# 1

# %%
df["deck"].bfill(inplace = True)
cnt3=df['deck'].isna().sum()
print(cnt3)
# Out:
# 0

# %%
df["embarked"].bfill(inplace=True) 
cnt4=df['embarked'].isna().sum() 
print(cnt4)
# Out:
# 0

# %%
df["embark_town"].bfill(inplace = True) 
cnt5=df['embark_town'].isna().sum()  
print(cnt5)
# Out:
# 0

# %%
df.isna().sum()
# Out:
# survived       0
# pclass         0
# sex            0
# age            0
# sibsp          0
# parch          0
# fare           0
# embarked       0
# class          0
# who            0
# adult_male     0
# deck           0
# embark_town    0
# alive          0
# alone          0
# dtype: int64

# %%
sns.countplot(x=df["sex"],data=df)
mat.show()

# %%
sns.countplot(x=df["survived"],data=df)
mat.show()

# %%
sns.boxplot(x=df["age"])
mat.show()

# %%
sns.boxplot(x=df["survived"])
mat.show()

# %%
sns.boxplot(x=df["fare"])
mat.show()

# %%
mat.hist(df["age"])
mat.show()

# %%
sns.catplot(x="sex",hue="survived",kind="count",data=df)
mat.show()

# %%
numeric_cols = ['age', 'survived', 'sex', 'parch','fare']
sns.boxplot(data=df[numeric_cols])
mat.show()

# %%
sex_count = df.groupby('sex')['sex'].count()
sex_count
# Out:
# sex
# female    314
# male      577
# Name: sex, dtype: int64

# %%
mat.figure(figsize=(7,7))
mat.title('Grouped by gender')
mat.pie(sex_count.values, labels=['male', 'female'], 
 autopct='%1.1f%%', textprops={'fontsize':13})
mat.show()

# %%
sns.histplot(df['age'],kde=False,color="orange",bins=30)
mat.title("Passengers By Age")
mat.show()

# %%
sns.histplot(df['fare'],kde=False,color="blue",bins=30)
mat.title("Fare for Passengers")
mat.show()

# %%
df['fare'].hist(bins = 30, figsize=(8,4))
# Out:
# <Axes: >

# %%
sns.jointplot(x = "survived", y = "age", kind = "scatter", data = df)

# %%
sns.jointplot(y='fare',x='survived',data=df,kind="hex")

# %%
df.hist(figsize=(10,10));

# %%
sns.histplot(df['fare'], kde=False, color="blue", bins=30) 
mat.title("Ticket Price Distribution")
mat.xlabel("Fare")
mat.ylabel("Frequency")
mat.show()
